# %% [markdown]
# <a href="https://colab.research.google.com/github/yun890503/ClassModel_torch_nn_Module/blob/main/class_Model(torch_nn_Module).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchviz
import torch
import torch.nn as nn

from torchviz import make_dot

class Model(nn.Module):
    def __init__(self, input_size, output_size):
        super(Model, self).__init__()
        self.hidden1 = torch.nn.Linear(input_size, 64)
        self.hidden2 = torch.nn.Linear(64, 32)
        self.predict = torch.nn.Linear(32, output_size)

    def forward(self, x):
        output1 = torch.relu(self.hidden1(x))
        output2 = torch.relu(self.hidden2(output1))
        output = torch.sigmoid(self.predict(output2))
        return output

# 創建一個 Model 的實例
input_size = 784
output_size = 10
model = Model(input_size, output_size)

# 創建一個虛擬的輸入 tensor
dummy_input = torch.randn(1, input_size)

# 使用 torchviz 繪製構造圖
make_dot(model(dummy_input), params=dict(model.named_parameters()))
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4131 sha256=675f47f45e27e00de8ba11c578f2600dee2a766f62a20ffd2a1b3c53f76d8e71
#   Stored in directory: /root/.cache/pip/wheels/4c/97/88/a02973217949e0db0c9f4346d154085f4725f99c4f15a87094
# Successfully built torchviz
# ...
